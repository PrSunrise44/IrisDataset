# %% [markdown]
# # Python Practice
# ## Data Career Jumpstart

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Import the iris dataset

# %%
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris['data'], columns=iris['feature_names'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# From what you read, describe the data set below.
#
# Description:

# %% [markdown]
# **Make** a new column called *species* that includes the species.

# %%
df['species'] = iris['target']

# %% [markdown]
# Now that we have a species column, display a snippet of the dataframe

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# You'll notice the species column is numeric, it doesn't have names. How many species are there? What are the species? *review reading if you don't remember*
#
# How many species are there? **3**
#
# What are the species? **setosa, versicolor, virginica**

# %% [markdown]
# Let's check your answer with Python to ensure the dataset matches our domain knowledge.
#
# Let's figure out how many species are in the column.
#
# *hint: how many UNIQUE species are there?*

# %%
len(df['species'].unique())
# Out:
# 3

# %%
specie = df['species']
specie.unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# Okay those species as numbers don't mean much to me, the names of the species can be found by running the cell below.

# %%
name = iris['target_names']

# %% [markdown]
# Create a new column in the dataframe named *species_name* and have it match the correct species names

# %%
iris_dict = {0:'setosa', 1:'versicolor',2: 'virginica'}
df['species_name'] = df['species'].map(iris_dict)

# %% [markdown]
# Show the last 8 rows of the updated dataframe

# %%
df.tail(8)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species species_name
# 142        2    virginica
# 143        2    virginica
# 144        2    virginica
# 145        2    virginica
# 146        2    virginica
# 147        2    virginica
# 148        2    virginica
# 149        2    virginica

# %% [markdown]
# How many of each species are there?

# %%
df['species_name'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species_name, dtype: int64

# %% [markdown]
# What is the average sepal length?

# %%
df['sepal length (cm)'].mean()
# Out:
# 5.843333333333335

# %% [markdown]
# How many flowers have a sepal length grater than 5cm?

# %%
five = df['sepal length (cm)']> 5
five.value_counts(sort = True)
# Out:
# True     118
# False     32
# Name: sepal length (cm), dtype: int64

# %% [markdown]
# Create a scatterplot matrix (pair plot) with the numerical data as the axis and the species name as the categories / colors.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, hue="species", palette="tab10", markers=["o", "s", "D"])
